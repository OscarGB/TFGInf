# %% [markdown]
# # Temporal Variables
# Este notebook realiza una modificacion de las variables para incluir datos del pasado y no solo del año actual.

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_parquet("dataset.parquet")

# %%
df = data.copy()
indexNames = df[ df.Year < 1992 ].index
df.drop(indexNames , inplace=True)
df.head()
# Out:
#    Year  COU  Country_Australia  Country_Austria  Country_Belgium  \
# 2  1992  AUS                  1                0                0
# 3  1993  AUS                  1                0                0
# 4  1994  AUS                  1                0                0
# 5  1995  AUS                  1                0                0
# 6  1996  AUS                  1                0                0
#
#    Country_Brazil  Country_Canada  Country_Chile  \
# 2               0               0              0
# 3               0               0              0
# 4               0               0              0
# 5               0               0              0
# 6               0               0              0
#
#    Country_China (People's Republic of)  Country_Colombia  ...  \
# 2                                     0                 0  ...
# 3                                     0                 0  ...
# 4                                     0                 0  ...
# ...

# %%
df.columns
# Out:
# Index(['Year', 'COU', 'Country_Australia', 'Country_Austria',
#        'Country_Belgium', 'Country_Brazil', 'Country_Canada', 'Country_Chile',
#        'Country_China (People's Republic of)', 'Country_Colombia',
#        'Country_Costa Rica', 'Country_Czech Republic', 'Country_Denmark',
#        'Country_Estonia', 'Country_Finland', 'Country_France',
#        'Country_Germany', 'Country_Greece', 'Country_Hungary',
#        'Country_Iceland', 'Country_India', 'Country_Indonesia',
#        'Country_Ireland', 'Country_Israel', 'Country_Italy', 'Country_Japan',
#        'Country_Korea', 'Country_Latvia', 'Country_Lithuania',
#        'Country_Luxembourg', 'Country_Mexico', 'Country_Netherlands',
#        'Country_New Zealand', 'Country_Norway', 'Country_Poland',
#        'Country_Portugal', 'Country_Russia', 'Country_Slovak Republic',
#        'Country_Slovenia', 'Country_Spain', 'Country_Sweden',
#        'Country_Switzerland', 'Country_Turkey', 'Country_United Kingdom',
# ...

# %%
df["Last Year Municipal"] = 0
for c in df.COU.unique():
    for y in df.Year.unique():
        df.loc[(df.COU == c) & (df.Year == y), "Last Year Municipal"] = \
            float(data[(data.COU == c) & (data.Year == y-1)].Municipal)
df.head()
# Out:
#    Year  COU  Country_Australia  Country_Austria  Country_Belgium  \
# 2  1992  AUS                  1                0                0
# 3  1993  AUS                  1                0                0
# 4  1994  AUS                  1                0                0
# 5  1995  AUS                  1                0                0
# 6  1996  AUS                  1                0                0
#
#    Country_Brazil  Country_Canada  Country_Chile  \
# 2               0               0              0
# 3               0               0              0
# 4               0               0              0
# 5               0               0              0
# 6               0               0              0
#
#    Country_China (People's Republic of)  Country_Colombia  ...  Tourism  \
# 2                                     0                 0  ...    2.907
# 3                                     0                 0  ...    2.907
# ...

# %%
df["Last Year Household"] = 0
for c in df.COU.unique():
    for y in df.Year.unique():
        df.loc[(df.COU == c) & (df.Year == y), "Last Year Household"] = \
            float(data[(data.COU == c) & (data.Year == y-1)].Household)
df.head()
# Out:
#    Year  COU  Country_Australia  Country_Austria  Country_Belgium  \
# 2  1992  AUS                  1                0                0
# 3  1993  AUS                  1                0                0
# 4  1994  AUS                  1                0                0
# 5  1995  AUS                  1                0                0
# 6  1996  AUS                  1                0                0
#
#    Country_Brazil  Country_Canada  Country_Chile  \
# 2               0               0              0
# 3               0               0              0
# 4               0               0              0
# 5               0               0              0
# 6               0               0              0
#
#    Country_China (People's Republic of)  Country_Colombia  ...       Area  \
# 2                                     0                 0  ...  7741220.0
# 3                                     0                 0  ...  7741220.0
# ...

# %%
df["Last Year Recovered"] = 0
for c in df.COU.unique():
    for y in df.Year.unique():
        df.loc[(df.COU == c) & (df.Year == y), "Last Year Recovered"] = \
            float(data[(data.COU == c) & (data.Year == y-1)].Recovered)
df.head()
# Out:
#    Year  COU  Country_Australia  Country_Austria  Country_Belgium  \
# 2  1992  AUS                  1                0                0
# 3  1993  AUS                  1                0                0
# 4  1994  AUS                  1                0                0
# 5  1995  AUS                  1                0                0
# 6  1996  AUS                  1                0                0
#
#    Country_Brazil  Country_Canada  Country_Chile  \
# 2               0               0              0
# 3               0               0              0
# 4               0               0              0
# 5               0               0              0
# 6               0               0              0
#
#    Country_China (People's Republic of)  Country_Colombia  ...   Built Area  \
# 2                                     0                 0  ...  936919.8566
# 3                                     0                 0  ...  936919.8566
# ...

# %%
df["Last Year Recicled"] = 0
for c in df.COU.unique():
    for y in df.Year.unique():
        df.loc[(df.COU == c) & (df.Year == y), "Last Year Recicled"] = \
            float(data[(data.COU == c) & (data.Year == y-1)].Recicled)
df.head()
# Out:
#    Year  COU  Country_Australia  Country_Austria  Country_Belgium  \
# 2  1992  AUS                  1                0                0
# 3  1993  AUS                  1                0                0
# 4  1994  AUS                  1                0                0
# 5  1995  AUS                  1                0                0
# 6  1996  AUS                  1                0                0
#
#    Country_Brazil  Country_Canada  Country_Chile  \
# 2               0               0              0
# 3               0               0              0
# 4               0               0              0
# 5               0               0              0
# 6               0               0              0
#
#    Country_China (People's Republic of)  Country_Colombia  ...  Municipal  \
# 2                                     0                 0  ...    12000.0
# 3                                     0                 0  ...    12000.0
# ...

# %%
df["Last Year Compost"] = 0
for c in df.COU.unique():
    for y in df.Year.unique():
        df.loc[(df.COU == c) & (df.Year == y), "Last Year Compost"] = \
            float(data[(data.COU == c) & (data.Year == y-1)].Compost)
df.head()
# Out:
#    Year  COU  Country_Australia  Country_Austria  Country_Belgium  \
# 2  1992  AUS                  1                0                0
# 3  1993  AUS                  1                0                0
# 4  1994  AUS                  1                0                0
# 5  1995  AUS                  1                0                0
# 6  1996  AUS                  1                0                0
#
#    Country_Brazil  Country_Canada  Country_Chile  \
# 2               0               0              0
# 3               0               0              0
# 4               0               0              0
# 5               0               0              0
# 6               0               0              0
#
#    Country_China (People's Republic of)  Country_Colombia  ...  Household  \
# 2                                     0                 0  ...     7000.0
# 3                                     0                 0  ...     7000.0
# ...

# %%
df["Last Year Built"] = 0
for c in df.COU.unique():
    for y in df.Year.unique():
        df.loc[(df.COU == c) & (df.Year == y), "Last Year Built"] = \
            float(data[(data.COU == c) & (data.Year == y-1)].Built)
df.head()
# Out:
#    Year  COU  Country_Australia  Country_Austria  Country_Belgium  \
# 2  1992  AUS                  1                0                0
# 3  1993  AUS                  1                0                0
# 4  1994  AUS                  1                0                0
# 5  1995  AUS                  1                0                0
# 6  1996  AUS                  1                0                0
#
#    Country_Brazil  Country_Canada  Country_Chile  \
# 2               0               0              0
# 3               0               0              0
# 4               0               0              0
# 5               0               0              0
# 6               0               0              0
#
#    Country_China (People's Republic of)  Country_Colombia  ...  Recovered  \
# 2                                     0                 0  ...     2701.0
# 3                                     0                 0  ...     2701.0
# ...

# %%
df["Difference Built"] = 0
for c in df.COU.unique():
    for y in df.Year.unique():
        df.loc[(df.COU == c) & (df.Year == y), "Difference Built"] = \
            float(data[(data.COU == c) & (data.Year == y)].Built) - float(data[(data.COU == c) & (data.Year == y-1)].Built)
df.head()
# Out:
#    Year  COU  Country_Australia  Country_Austria  Country_Belgium  \
# 2  1992  AUS                  1                0                0
# 3  1993  AUS                  1                0                0
# 4  1994  AUS                  1                0                0
# 5  1995  AUS                  1                0                0
# 6  1996  AUS                  1                0                0
#
#    Country_Brazil  Country_Canada  Country_Chile  \
# 2               0               0              0
# 3               0               0              0
# 4               0               0              0
# 5               0               0              0
# 6               0               0              0
#
#    Country_China (People's Republic of)  Country_Colombia  ...  Recicled  \
# 2                                     0                 0  ...    2701.0
# 3                                     0                 0  ...    2701.0
# ...

# %%
df["Mean Built"] = 0
for c in df.COU.unique():
    for y in df.Year.unique():
        df.loc[(df.COU == c) & (df.Year == y), "Mean Built"] = \
            np.mean(data[(data.COU == c) & (data.Year < y)].Built)
df.head()
# Out:
#    Year  COU  Country_Australia  Country_Austria  Country_Belgium  \
# 2  1992  AUS                  1                0                0
# 3  1993  AUS                  1                0                0
# 4  1994  AUS                  1                0                0
# 5  1995  AUS                  1                0                0
# 6  1996  AUS                  1                0                0
#
#    Country_Brazil  Country_Canada  Country_Chile  \
# 2               0               0              0
# 3               0               0              0
# 4               0               0              0
# 5               0               0              0
# 6               0               0              0
#
#    Country_China (People's Republic of)  Country_Colombia  ...  Compost  \
# 2                                     0                 0  ...    814.0
# 3                                     0                 0  ...    814.0
# ...

# %%
df['Last Year Below Secundary'] = 0
for c in df.COU.unique():
    for y in df.Year.unique():
        df.loc[(df.COU == c) & (df.Year == y), 'Last Year Below Secundary'] = \
            float(data[(data.COU == c) & (data.Year == y-1)]['Below Secundary'])
df.head()
# Out:
#    Year  COU  Country_Australia  Country_Austria  Country_Belgium  \
# 2  1992  AUS                  1                0                0
# 3  1993  AUS                  1                0                0
# 4  1994  AUS                  1                0                0
# 5  1995  AUS                  1                0                0
# 6  1996  AUS                  1                0                0
#
#    Country_Brazil  Country_Canada  Country_Chile  \
# 2               0               0              0
# 3               0               0              0
# 4               0               0              0
# 5               0               0              0
# 6               0               0              0
#
#    Country_China (People's Republic of)  Country_Colombia  ...  Disposal  \
# 2                                     0                 0  ...    6202.0
# 3                                     0                 0  ...    6202.0
# ...

# %%
df["Difference Below Secundary"] = 0
for c in df.COU.unique():
    for y in df.Year.unique():
        df.loc[(df.COU == c) & (df.Year == y), "Difference Below Secundary"] = \
            float(data[(data.COU == c) & (data.Year == y)]['Below Secundary']) - float(data[(data.COU == c) & (data.Year == y-1)]['Below Secundary'])
df.head()
# Out:
#    Year  COU  Country_Australia  Country_Austria  Country_Belgium  \
# 2  1992  AUS                  1                0                0
# 3  1993  AUS                  1                0                0
# 4  1994  AUS                  1                0                0
# 5  1995  AUS                  1                0                0
# 6  1996  AUS                  1                0                0
#
#    Country_Brazil  Country_Canada  Country_Chile  \
# 2               0               0              0
# 3               0               0              0
# 4               0               0              0
# 5               0               0              0
# 6               0               0              0
#
#    Country_China (People's Republic of)  Country_Colombia  ...  \
# 2                                     0                 0  ...
# 3                                     0                 0  ...
# 4                                     0                 0  ...
# ...

# %%
df['Last Year Population'] = 0
for c in df.COU.unique():
    for y in df.Year.unique():
        df.loc[(df.COU == c) & (df.Year == y), 'Last Year Population'] = \
            float(data[(data.COU == c) & (data.Year == y-1)]['Population'])
df.head()
# Out:
#    Year  COU  Country_Australia  Country_Austria  Country_Belgium  \
# 2  1992  AUS                  1                0                0
# 3  1993  AUS                  1                0                0
# 4  1994  AUS                  1                0                0
# 5  1995  AUS                  1                0                0
# 6  1996  AUS                  1                0                0
#
#    Country_Brazil  Country_Canada  Country_Chile  \
# 2               0               0              0
# 3               0               0              0
# 4               0               0              0
# 5               0               0              0
# 6               0               0              0
#
#    Country_China (People's Republic of)  Country_Colombia  ...  \
# 2                                     0                 0  ...
# 3                                     0                 0  ...
# 4                                     0                 0  ...
# ...

# %%
df["Difference Population"] = 0
for c in df.COU.unique():
    for y in df.Year.unique():
        df.loc[(df.COU == c) & (df.Year == y), "Difference Population"] = \
            float(data[(data.COU == c) & (data.Year == y)]['Population']) - float(data[(data.COU == c) & (data.Year == y-1)]['Population'])
df.head()
# Out:
#    Year  COU  Country_Australia  Country_Austria  Country_Belgium  \
# 2  1992  AUS                  1                0                0
# 3  1993  AUS                  1                0                0
# 4  1994  AUS                  1                0                0
# 5  1995  AUS                  1                0                0
# 6  1996  AUS                  1                0                0
#
#    Country_Brazil  Country_Canada  Country_Chile  \
# 2               0               0              0
# 3               0               0              0
# 4               0               0              0
# 5               0               0              0
# 6               0               0              0
#
#    Country_China (People's Republic of)  Country_Colombia  ...  \
# 2                                     0                 0  ...
# 3                                     0                 0  ...
# 4                                     0                 0  ...
# ...

# %%
df['Last Year Tourism'] = 0
for c in df.COU.unique():
    for y in df.Year.unique():
        df.loc[(df.COU == c) & (df.Year == y), 'Last Year Tourism'] = \
            float(data[(data.COU == c) & (data.Year == y-1)]['Tourism'])
df.head()
# Out:
#    Year  COU  Country_Australia  Country_Austria  Country_Belgium  \
# 2  1992  AUS                  1                0                0
# 3  1993  AUS                  1                0                0
# 4  1994  AUS                  1                0                0
# 5  1995  AUS                  1                0                0
# 6  1996  AUS                  1                0                0
#
#    Country_Brazil  Country_Canada  Country_Chile  \
# 2               0               0              0
# 3               0               0              0
# 4               0               0              0
# 5               0               0              0
# 6               0               0              0
#
#    Country_China (People's Republic of)  Country_Colombia  ...  \
# 2                                     0                 0  ...
# 3                                     0                 0  ...
# 4                                     0                 0  ...
# ...

# %%
df["Difference Tourism"] = 0
for c in df.COU.unique():
    for y in df.Year.unique():
        df.loc[(df.COU == c) & (df.Year == y), "Difference Tourism"] = \
            float(data[(data.COU == c) & (data.Year == y)]['Tourism']) - float(data[(data.COU == c) & (data.Year == y-1)]['Tourism'])
df.head()
# Out:
#    Year  COU  Country_Australia  Country_Austria  Country_Belgium  \
# 2  1992  AUS                  1                0                0
# 3  1993  AUS                  1                0                0
# 4  1994  AUS                  1                0                0
# 5  1995  AUS                  1                0                0
# 6  1996  AUS                  1                0                0
#
#    Country_Brazil  Country_Canada  Country_Chile  \
# 2               0               0              0
# 3               0               0              0
# 4               0               0              0
# 5               0               0              0
# 6               0               0              0
#
#    Country_China (People's Republic of)  Country_Colombia  ...  \
# 2                                     0                 0  ...
# 3                                     0                 0  ...
# 4                                     0                 0  ...
# ...

# %%
df.to_parquet("time_dataset.parquet")
