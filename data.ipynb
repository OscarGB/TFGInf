# %% [markdown]
# # Notebook para pruebas, no tomar en cuenta

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

# %%
dfMUNW = pd.read_parquet("waste.parquet")

# %%
dfMUNW.VAR.unique()
# Out:
# array(['MUNICIPAL', 'HOUSEHOLD', 'TREATMENT', 'RECOVERY', 'RECYCLING',
#        'INCINERATION_WITH', 'DISPOSAL', 'LANDFILL', 'RECYCLING_SHARE',
#        'INC_WITH_SHARE', 'LANDF_SHARE', 'OTHMUN', 'COMPOST', 'OTH_RECOV',
#        'INCINERATION_WITHOUT', 'INCINERATION', 'MAT_RECOV_SHARE',
#        'COMPST_SHARE', 'INC_WITHOUT_SHARE', 'INC_SHARE', 'OTH_DISP',
#        'MW_CAP', 'HOUSE_LIKE', 'BULKY', 'WEEE', 'INDEX2000', 'INDEX1990',
#        'DISP_SHARE', 'RECOV_SHARE'], dtype=object)

# %%
pd.set_option('display.max_rows',260)
dfMUNW.loc[dfMUNW['Country'] == "Spain"].loc[dfMUNW['VAR'] == 'RECYCLING'].plot('YEA', 'Value')

# %%
dfMUNW.loc[dfMUNW['Country'] == "Spain"].loc[dfMUNW['VAR'] == 'MUNICIPAL']
# Out:
#       COU Country        VAR                   Variable   YEA  Year Unit Code  \
# 9372  ESP   Spain  MUNICIPAL  Municipal waste generated  1995  1995     TONNE
# 9373  ESP   Spain  MUNICIPAL  Municipal waste generated  1996  1996     TONNE
# 9374  ESP   Spain  MUNICIPAL  Municipal waste generated  1997  1997     TONNE
# 9375  ESP   Spain  MUNICIPAL  Municipal waste generated  1998  1998     TONNE
# 9376  ESP   Spain  MUNICIPAL  Municipal waste generated  1999  1999     TONNE
# 9377  ESP   Spain  MUNICIPAL  Municipal waste generated  2000  2000     TONNE
# 9378  ESP   Spain  MUNICIPAL  Municipal waste generated  2001  2001     TONNE
# 9379  ESP   Spain  MUNICIPAL  Municipal waste generated  2002  2002     TONNE
# 9380  ESP   Spain  MUNICIPAL  Municipal waste generated  2003  2003     TONNE
# 9381  ESP   Spain  MUNICIPAL  Municipal waste generated  2004  2004     TONNE
# 9382  ESP   Spain  MUNICIPAL  Municipal waste generated  2005  2005     TONNE
# ...

# %%
RationalQuadraticdfMUNW.loc[dfMUNW['Country'] == "Spain"]
# Out:
#        COU Country                   VAR  \
# 9372   ESP   Spain             MUNICIPAL
# 9373   ESP   Spain             MUNICIPAL
# 9374   ESP   Spain             MUNICIPAL
# 9375   ESP   Spain             MUNICIPAL
# 9376   ESP   Spain             MUNICIPAL
# 9377   ESP   Spain             MUNICIPAL
# 9378   ESP   Spain             MUNICIPAL
# 9379   ESP   Spain             MUNICIPAL
# 9380   ESP   Spain             MUNICIPAL
# 9381   ESP   Spain             MUNICIPAL
# 9382   ESP   Spain             MUNICIPAL
# 9383   ESP   Spain             MUNICIPAL
# 9384   ESP   Spain             MUNICIPAL
# 9385   ESP   Spain             MUNICIPAL
# 9386   ESP   Spain             MUNICIPAL
# 9387   ESP   Spain             MUNICIPAL
# 9388   ESP   Spain             MUNICIPAL
# 9389   ESP   Spain             MUNICIPAL
# 9390   ESP   Spain             MUNICIPAL
# 9391   ESP   Spain             MUNICIPAL
# 9392   ESP   Spain             MUNICIPAL
# 9393   ESP   Spain             MUNICIPAL
# ...

# %%
dfMUNW.COU.unique()
# Out:
# array(['AUS', 'AUT', 'BEL', 'CAN', 'CZE', 'DNK', 'FIN', 'FRA', 'DEU',
#        'GRC', 'HUN', 'ISL', 'IRL', 'ITA', 'JPN', 'KOR', 'LUX', 'MEX',
#        'NLD', 'NZL', 'NOR', 'POL', 'PRT', 'SVK', 'ESP', 'SWE', 'CHE',
#        'TUR', 'GBR', 'USA', 'BRA', 'CHL', 'CHN', 'EST', 'IDN', 'ISR',
#        'RUS', 'SVN', 'OECD', 'OECDE', 'COL', 'LVA', 'CRI', 'IND', 'LTU',
#        'OECDAO', 'OECDAM'], dtype=object)

# %%
#edu = pd.read_csv("EdStatsData.csv")
#edu.head()
#for a in ['2020', '2025', '2030', '2035', '2040', '2045',
#       '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090',
#       '2095', '2100', 'Unnamed: 69']:
#    del edu[a]

# %%
education = pd.read_parquet("education.parquet")

# %%
#edu['Country Code'].unique()
# Out:
# array(['ARB', 'EAS', 'EAP', 'EMU', 'ECS', 'ECA', 'EUU', 'HPC', 'HIC',
#        'LCN', 'LAC', 'LDC', 'LMY', 'LIC', 'LMC', 'MEA', 'MNA', 'MIC',
#        'NAC', 'OED', 'SAS', 'SSF', 'SSA', 'UMC', 'WLD', 'AFG', 'ALB',
#        'DZA', 'ASM', 'AND', 'AGO', 'ATG', 'ARG', 'ARM', 'ABW', 'AUS',
#        'AUT', 'AZE', 'BHS', 'BHR', 'BGD', 'BRB', 'BLR', 'BEL', 'BLZ',
#        'BEN', 'BMU', 'BTN', 'BOL', 'BIH', 'BWA', 'BRA', 'VGB', 'BRN',
#        'BGR', 'BFA', 'BDI', 'CPV', 'KHM', 'CMR', 'CAN', 'CYM', 'CAF',
#        'TCD', 'CHI', 'CHL', 'CHN', 'COL', 'COM', 'COD', 'COG', 'CRI',
#        'CIV', 'HRV', 'CUB', 'CUW', 'CYP', 'CZE', 'DNK', 'DJI', 'DMA',
#        'DOM', 'ECU', 'EGY', 'SLV', 'GNQ', 'ERI', 'EST', 'ETH', 'FRO',
#        'FJI', 'FIN', 'FRA', 'PYF', 'GAB', 'GMB', 'GEO', 'DEU', 'GHA',
#        'GIB', 'GRC', 'GRL', 'GRD', 'GUM', 'GTM', 'GIN', 'GNB', 'GUY',
#        'HTI', 'HND', 'HKG', 'HUN', 'ISL', 'IND', 'IDN', 'IRN', 'IRQ',
# ...

# %%
#for a in dfMUNW.COU.unique():
#    if a not in edu['Country Code'].unique():
#        print(a)
# Out:
# OECD
# OECDE
# OECDAO
# OECDAM

# %%
#education = edu[edu['Country Code'].isin(dfMUNW.COU.unique())]

# %%
education['Country Code'].unique()
# Out:
# array(['AUS', 'AUT', 'BEL', 'BRA', 'CAN', 'CHL', 'CHN', 'COL', 'CRI',
#        'CZE', 'DNK', 'EST', 'FIN', 'FRA', 'DEU', 'GRC', 'HUN', 'ISL',
#        'IND', 'IDN', 'IRL', 'ISR', 'ITA', 'JPN', 'KOR', 'LVA', 'LTU',
#        'LUX', 'MEX', 'NLD', 'NZL', 'NOR', 'POL', 'PRT', 'RUS', 'SVK',
#        'SVN', 'ESP', 'SWE', 'CHE', 'TUR', 'GBR', 'USA'], dtype=object)

# %%
#education.to_parquet("education.parquet")

# %%
#edu.loc[edu['Country Code'] == "ESP"]
# Out:
#        Country Name Country Code  \
# 743995        Spain          ESP
# 743996        Spain          ESP
# 743997        Spain          ESP
# 743998        Spain          ESP
# 743999        Spain          ESP
# ...             ...          ...
# 747655        Spain          ESP
# 747656        Spain          ESP
# 747657        Spain          ESP
# 747658        Spain          ESP
# 747659        Spain          ESP
#
#                                            Indicator Name  \
# 743995  Adjusted net enrolment rate, lower secondary, ...
# 743996  Adjusted net enrolment rate, lower secondary, ...
# 743997  Adjusted net enrolment rate, lower secondary, ...
# 743998  Adjusted net enrolment rate, lower secondary, ...
# 743999  Adjusted net enrolment rate, primary, both sex...
# ...                                                   ...
# 747655  Youth illiterate population, 15-24 years, male...
# 747656  Youth literacy rate, population 15-24 years, b...
# ...

# %%
construido = pd.read_csv("porcentaje construido.csv")
construido = construido[construido['COU'].isin(dfMUNW.COU.unique())]

# %%
construido.to_parquet("construido.parquet")

# %%
poblacion = pd.read_csv("poblacion total.csv")
poblacion = poblacion[poblacion['LOCATION'].isin(dfMUNW.COU.unique())]

# %%
poblacion.to_parquet("poblacion.parquet")

# %%
renta = pd.read_csv("renta per capita.csv")
renta = renta[renta['LOCATION'].isin(dfMUNW.COU.unique())]

# %%
renta.to_parquet("renta.parquet")

# %%
over65 = pd.read_csv("Poblacion over 65.csv")
over65 = over65[over65['COU'].isin(dfMUNW.COU.unique())]

# %%
over65.to_parquet("over65.parquet")

# %%
median = pd.read_csv("median income.csv")
median = median[median['LOCATION'].isin(dfMUNW.COU.unique())]

# %%
median.to_parquet("income.parquet")

# %%
tourism = pd.read_csv("tourism.csv")
tourism = tourism[tourism['COUNTRY'].isin(dfMUNW.COU.unique())]

# %%
tourism.to_parquet("tourism.parquet")

# %%
dfMUNW.to_parquet("waste.parquet")

# %%
construido = pd.read_parquet("construido.parquet")
educacion = pd.read_parquet("education.parquet")
income = pd.read_parquet("income.parquet")
poblacion = pd.read_parquet("poblacion.parquet")
renta = pd.read_parquet("renta.parquet")
turismo = pd.read_parquet("tourism.parquet")
waste = pd.read_parquet("waste.parquet")

# %%
print(list(educacion["Indicator Name"].unique()))
# Out:
# ['Adjusted net enrolment rate, lower secondary, both sexes (%)', 'Adjusted net enrolment rate, lower secondary, female (%)', 'Adjusted net enrolment rate, lower secondary, gender parity index (GPI)', 'Adjusted net enrolment rate, lower secondary, male (%)', 'Adjusted net enrolment rate, primary, both sexes (%)', 'Adjusted net enrolment rate, primary, female (%)', 'Adjusted net enrolment rate, primary, gender parity index (GPI)', 'Adjusted net enrolment rate, primary, male (%)', 'Adjusted net enrolment rate, upper secondary, both sexes (%)', 'Adjusted net enrolment rate, upper secondary, female (%)', 'Adjusted net enrolment rate, upper secondary, gender parity index (GPI)', 'Adjusted net enrolment rate, upper secondary, male (%)', 'Adjusted net intake rate to Grade 1 of primary education, both sexes (%)', 'Adjusted net intake rate to Grade 1 of primary education, female (%)', 'Adjusted net intake rate to Grade 1 of primary education, gender parity index (GPI)', 'Adjusted net intake ra
# ...

# %%
educacion[educacion["Indicator Name"] == 'Adjusted net enrolment rate, lower secondary, both sexes (%)']
# Out:
#               Country Name Country Code  \
# 128275           Australia          AUS
# 131940             Austria          AUT
# 157595             Belgium          BEL
# 186915              Brazil          BRA
# 219900              Canada          CAN
# 238225               Chile          CHL
# 241890               China          CHN
# 245555            Colombia          COL
# 260215          Costa Rica          CRI
# 282205      Czech Republic          CZE
# 285870             Denmark          DNK
# 318855             Estonia          EST
# 333515             Finland          FIN
# 337180              France          FRA
# 355505             Germany          DEU
# 366500              Greece          GRC
# 406815             Hungary          HUN
# 410480             Iceland          ISL
# 414145               India          IND
# 417810           Indonesia          IDN
# 428805             Ireland          IRL
# 436135              Israel          ISR
# ...

# %%
educacion.dropna()
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, Indicator Code, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]
# Index: []
#
# [0 rows x 32 columns]

# %%
educacion.drop([str(a) for a in range(1970,1990)], axis=1, inplace=True)
educacion.head()
# Out:
#        Country Name Country Code  \
# 128275    Australia          AUS
# 128276    Australia          AUS
# 128277    Australia          AUS
# 128278    Australia          AUS
# 128279    Australia          AUS
#
#                                            Indicator Name  Indicator Code  \
# 128275  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2
# 128276  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F
# 128277  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI
# 128278  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M
# 128279  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR
#
#         1990  1991  1992       1993       1994       1995  ...       2008  \
# 128275   NaN   NaN   NaN  87.921043  87.341232  87.241653  ...  86.895981
# 128276   NaN   NaN   NaN  89.008247  88.418510  88.097031  ...  88.926842
# 128277   NaN   NaN   NaN   1.024380   1.024320   1.019300  ...   1.045980
# ...

# %%
educacion2 = pd.read_csv("educacion2.csv")
educacion2 = educacion2[educacion2['LOCATION'].isin(dfMUNW.COU.unique())]

# %%
educacion2.to_parquet("education2.parquet")

# %%
educacion2
# Out:
#     LOCATION INDICATOR  SUBJECT   MEASURE FREQUENCY  TIME      Value  \
# 0        AUS  EDUADULT  BUPPSRY  PC_25_64         A  1991  44.127056
# 1        AUS  EDUADULT  BUPPSRY  PC_25_64         A  1993  47.159046
# 2        AUS  EDUADULT  BUPPSRY  PC_25_64         A  1994  49.802025
# 3        AUS  EDUADULT  BUPPSRY  PC_25_64         A  1995  44.935852
# 4        AUS  EDUADULT  BUPPSRY  PC_25_64         A  1997  46.695274
# ..       ...       ...      ...       ...       ...   ...        ...
# 883      CRI  EDUADULT  BUPPSRY  PC_25_64         A  2014  59.457653
# 884      CRI  EDUADULT  BUPPSRY  PC_25_64         A  2015  60.632359
# 885      CRI  EDUADULT  BUPPSRY  PC_25_64         A  2016  60.063385
# 886      CRI  EDUADULT  BUPPSRY  PC_25_64         A  2017  60.489311
# 887      CRI  EDUADULT  BUPPSRY  PC_25_64         A  2018  60.770302
#
#      Flag Codes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# ...

# %%
income.columns
# Out:
# Index(['LOCATION', 'Country', 'MEASURE', 'Measure', 'AGE', 'Age group',
#        'DEFINITION', 'Definition', 'METHODO', 'Methodology', 'TIME', 'Year',
#        'Unit Code', 'Unit', 'PowerCode Code', 'PowerCode',
#        'Reference Period Code', 'Reference Period', 'Value', 'Flag Codes',
#        'Flags'],
#       dtype='object')

# %%
income[(income["MEASURE"] == "MEDIANC") & (income["METHODO"] == "METH2011")]
# Out:
#       LOCATION    Country  MEASURE                                    Measure  \
# 138        AUS  Australia  MEDIANC  Median disposable income (current prices)
# 139        AUS  Australia  MEDIANC  Median disposable income (current prices)
# 140        AUS  Australia  MEDIANC  Median disposable income (current prices)
# 141        AUS  Australia  MEDIANC  Median disposable income (current prices)
# 1272       BEL    Belgium  MEDIANC  Median disposable income (current prices)
# ...        ...        ...      ...                                        ...
# 56646      LTU  Lithuania  MEDIANC  Median disposable income (current prices)
# 56647      LTU  Lithuania  MEDIANC  Median disposable income (current prices)
# 56648      LTU  Lithuania  MEDIANC  Median disposable income (current prices)
# 56649      LTU  Lithuania  MEDIANC  Median disposable income (current prices)
# 56650      LTU  Lithuania  MEDIANC  Median disposable income (current prices)
#
# ...

# %%
over65[(over65.COU == "AUS") & (over65.UNIT == "EFFPEREF")]
# Out:
#          VAR                           Variable      UNIT  \
# 0   STRUSFPL  Population: 65 years old and over  EFFPEREF
# 1   STRUSFPL  Population: 65 years old and over  EFFPEREF
# 2   STRUSFPL  Population: 65 years old and over  EFFPEREF
# 3   STRUSFPL  Population: 65 years old and over  EFFPEREF
# 4   STRUSFPL  Population: 65 years old and over  EFFPEREF
# 5   STRUSFPL  Population: 65 years old and over  EFFPEREF
# 6   STRUSFPL  Population: 65 years old and over  EFFPEREF
# 7   STRUSFPL  Population: 65 years old and over  EFFPEREF
# 8   STRUSFPL  Population: 65 years old and over  EFFPEREF
# 9   STRUSFPL  Population: 65 years old and over  EFFPEREF
# 10  STRUSFPL  Population: 65 years old and over  EFFPEREF
# 11  STRUSFPL  Population: 65 years old and over  EFFPEREF
# 12  STRUSFPL  Population: 65 years old and over  EFFPEREF
# 13  STRUSFPL  Population: 65 years old and over  EFFPEREF
# 14  STRUSFPL  Population: 65 years old and over  EFFPEREF
# ...

# %%
poblacion.AGE.unique()
# Out:
# array(['TOTAL', '0_4', '05_9', '10_14', '15_19', '20_24', '25_29',
#        '30_34', '35_39', '40_44', '45_49', '50_54', '55_59', '60_64',
#        '65_69', '70_74', '75_79', '80_84', '85_OVER', '50_OVER',
#        'LESS_20', '15-64', '20-64', '65_OVER', '65_OVER_SHARE',
#        'LESS_15_SHARE', '15-24_SHARE', 'OAD15-64', 'TOTD20-64'],
#       dtype=object)

# %%
poblacion.head()
# Out:
#   LOCATION    Country SEX    Sex    AGE    Age  TIME  Time       Value  \
# 0      AUS  Australia   W  Women  TOTAL  Total  2005  2005  10157211.0
# 1      AUS  Australia   W  Women  TOTAL  Total  2006  2006  10291542.0
# 2      AUS  Australia   W  Women  TOTAL  Total  2007  2007  10473986.0
# 3      AUS  Australia   W  Women  TOTAL  Total  2008  2008  10677154.0
# 4      AUS  Australia   W  Women  TOTAL  Total  2009  2009  10890856.0
#
#    Flag Codes  Flags
# 0         NaN    NaN
# 1         NaN    NaN
# 2         NaN    NaN
# 3         NaN    NaN
# 4         NaN    NaN

# %%
renta.head()
# Out:
#   LOCATION    Country SUBJECT                                 Subject MEASURE  \
# 0      AUS  Australia   T_GDP  Gross Domestic Product (GDP); millions       C
# 1      AUS  Australia   T_GDP  Gross Domestic Product (GDP); millions       C
# 2      AUS  Australia   T_GDP  Gross Domestic Product (GDP); millions       C
# 3      AUS  Australia   T_GDP  Gross Domestic Product (GDP); millions       C
# 4      AUS  Australia   T_GDP  Gross Domestic Product (GDP); millions       C
#
#                              Measure  TIME  Time Unit Code               Unit  \
# 0  National currency, current prices  1970  1970    NATCUR  National currency
# 1  National currency, current prices  1971  1971    NATCUR  National currency
# 2  National currency, current prices  1972  1972    NATCUR  National currency
# 3  National currency, current prices  1973  1973    NATCUR  National currency
# 4  National currency, current prices  1974  1974    NATCUR  National currency
#
# ...

# %%
renta[renta.Measure == 'USD, current prices, current PPPs'].MEASURE.unique()
# Out:
# array(['CPC'], dtype=object)

# %%
renta.MEASURE.unique()
# Out:
# array(['C', 'CPC', 'VPVOB', 'PCTUS', 'PEHRS', 'GAP'], dtype=object)

# %%
turismo["Key indicator"].unique()
# Out:
# array(['Tourism GDP (direct) as % of total GDP',
#        'Total tourism employment (direct) as % of total employment',
#        'Tourism GVA (direct) as % of total GVA'], dtype=object)

# %%
turismo.head()
# Out:
#   COUNTRY    Country        KEY_IND_PC  \
# 0     AUS  Australia  KEYIND_TOURGDPPC
# 1     AUS  Australia  KEYIND_TOURGDPPC
# 2     AUS  Australia  KEYIND_TOURGDPPC
# 3     AUS  Australia  KEYIND_TOURGDPPC
# 4     AUS  Australia  KEYIND_TOURGDPPC
#
#                             Key indicator  YEAR  Year Unit Code        Unit  \
# 0  Tourism GDP (direct) as % of total GDP  2008  2008        PC  Percentage
# 1  Tourism GDP (direct) as % of total GDP  2009  2009        PC  Percentage
# 2  Tourism GDP (direct) as % of total GDP  2010  2010        PC  Percentage
# 3  Tourism GDP (direct) as % of total GDP  2011  2011        PC  Percentage
# 4  Tourism GDP (direct) as % of total GDP  2012  2012        PC  Percentage
#
#    PowerCode Code PowerCode  Reference Period Code  Reference Period  Value  \
# 0               0     Units                    NaN               NaN  2.907
# 1               0     Units                    NaN               NaN  2.830
# ...

# %%
waste.VAR.unique()
# Out:
# array(['MUNICIPAL', 'HOUSEHOLD', 'TREATMENT', 'RECOVERY', 'RECYCLING',
#        'INCINERATION_WITH', 'DISPOSAL', 'LANDFILL', 'RECYCLING_SHARE',
#        'INC_WITH_SHARE', 'LANDF_SHARE', 'OTHMUN', 'COMPOST', 'OTH_RECOV',
#        'INCINERATION_WITHOUT', 'INCINERATION', 'MAT_RECOV_SHARE',
#        'COMPST_SHARE', 'INC_WITHOUT_SHARE', 'INC_SHARE', 'OTH_DISP',
#        'MW_CAP', 'HOUSE_LIKE', 'BULKY', 'WEEE', 'INDEX2000', 'INDEX1990',
#        'DISP_SHARE', 'RECOV_SHARE'], dtype=object)

# %%
area = pd.read_csv("area.csv")
area = area[area['COU'].isin(dfMUNW.COU.unique())]

# %%
area.to_parquet("area.parquet")

# %%
cambio = pd.read_csv("tasa cambio.csv")
cambio = cambio[cambio['LOCATION'].isin(np.append(dfMUNW.COU.unique(),['EA19']))]
cambio = cambio[cambio['FREQUENCY'] == 'A']
cambio = cambio[cambio["TIME"] == '2019']

# %%
cambio.to_parquet("cambio.parquet")

# %%
np.append(dfMUNW.COU.unique(),['EA19'])
# Out:
# array(['AUS', 'AUT', 'BEL', 'CAN', 'CZE', 'DNK', 'FIN', 'FRA', 'DEU',
#        'GRC', 'HUN', 'ISL', 'IRL', 'ITA', 'JPN', 'KOR', 'LUX', 'MEX',
#        'NLD', 'NZL', 'NOR', 'POL', 'PRT', 'SVK', 'ESP', 'SWE', 'CHE',
#        'TUR', 'GBR', 'USA', 'BRA', 'CHL', 'CHN', 'EST', 'IDN', 'ISR',
#        'RUS', 'SVN', 'OECD', 'OECDE', 'COL', 'LVA', 'CRI', 'IND', 'LTU',
#        'OECDAO', 'OECDAM', 'EA19'], dtype=object)

# %%
cambio = pd.read_csv("tasa cambio.csv")

# %%
cambio[cambio.LOCATION == 'EA19']
# Out:
#     SUBJECT                                   Subject LOCATION  \
# 450    CCUS  Currency exchange rates, monthly average     EA19
# 451    CCUS  Currency exchange rates, monthly average     EA19
# 452    CCUS  Currency exchange rates, monthly average     EA19
# 453    CCUS  Currency exchange rates, monthly average     EA19
# 454    CCUS  Currency exchange rates, monthly average     EA19
# 455    CCUS  Currency exchange rates, monthly average     EA19
# 456    CCUS  Currency exchange rates, monthly average     EA19
# 457    CCUS  Currency exchange rates, monthly average     EA19
# 458    CCUS  Currency exchange rates, monthly average     EA19
# 459    CCUS  Currency exchange rates, monthly average     EA19
# 460    CCUS  Currency exchange rates, monthly average     EA19
# 461    CCUS  Currency exchange rates, monthly average     EA19
# 462    CCUS  Currency exchange rates, monthly average     EA19
# 463    CCUS  Currency exchange rates, monthly average     EA19
# ...

# %%
area.VAR.unique()
# Out:
# array(['FOREST', 'OTHER_P', 'LAND', 'ARABLE_P', 'ARABLE', 'AREA', 'MEAD',
#        'MEAD_P', 'OTHER', 'FOREST_P'], dtype=object)

# %%
df = pd.read_parquet("dataset.parquet")

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'COU', 'Built', 'Below Secundary', 'Income Median',
#        'Population', 'Over 65', 'Over 65 Percentage', 'Over 85',
#        'Over 85 Percentage', 'Over 50', 'Over 50 Percentage', 'Under 20',
#        'Under 20 Percentage', 'Income Per Capita', 'Tourism', 'Municipal',
#        'Household', 'Recovered', 'Recicled', 'Compost', 'Disposal', 'Area',
#        'Built Area'],
#       dtype='object')

# %%
Ys = df[['Municipal', 'Household', 'Recovered', 'Recicled', 'Compost', 'Disposal']]

# %%
Ys
# Out:
#       Municipal  Household  Recovered  Recicled  Compost  Disposal
# 0      12000.00   7000.000   2701.000  2701.000  814.000  6202.000
# 1      12000.00   7000.000   2701.000  2701.000  814.000  6202.000
# 2      12000.00   7000.000   2701.000  2701.000  814.000  6202.000
# 3      12000.00   7000.000   2701.000  2701.000  814.000  6202.000
# 4      12000.00   7000.000   2701.000  2701.000  814.000  6202.000
# ...         ...        ...        ...       ...      ...       ...
# 1199    1280.05    896.034    447.330   261.311   94.680   798.592
# 1200    1270.25    889.171    499.573   267.886  119.094   747.713
# 1201    1300.00    909.999    580.414   298.172  132.357   702.127
# 1202    1272.06    890.440    832.000   312.270  298.710   379.270
# 1203    1286.43    900.500    854.500   310.810  307.970   420.830
#
# [1204 rows x 6 columns]

# %%
X = df[[x for x in df.columns if x not in ['Municipal', 'Household', 'Recovered', 'Recicled', 'Compost', 'Disposal']]]

# %%
X
# Out:
#         Country  Year  COU    Built  Below Secundary  Income Median  \
# 0     Australia  1990  AUS  0.12103        44.127056        17368.0
# 1     Australia  1991  AUS  0.12103        44.127056        17368.0
# 2     Australia  1992  AUS  0.12103        44.127056        17368.0
# 3     Australia  1993  AUS  0.12103        47.159046        17368.0
# 4     Australia  1994  AUS  0.12103        49.802025        17368.0
# ...         ...   ...  ...      ...              ...            ...
# 1199  Lithuania  2013  LTU  0.53645         6.557359         4190.0
# 1200  Lithuania  2014  LTU  0.57301         8.824093         4190.0
# 1201  Lithuania  2015  LTU  0.57301         8.644216         4190.0
# 1202  Lithuania  2016  LTU  0.57301         7.484357         4190.0
# 1203  Lithuania  2017  LTU  0.57301         7.171962         4190.0
#
#       Population    Over 65  Over 65 Percentage   Over 85  Over 85 Percentage  \
# ...

# %%
df = pd.read_parquet("dataset.parquet")

# %%
df.iloc[df[["Below Secundary"]].idxmax()]
# Out:
#     Country  Year  COU    Built  Below Secundary  Income Median  Population  \
# 758  Turkey  1992  TUR  0.61617        86.381432   40578.373134   8451834.0
#
#        Over 65  Over 65 Percentage   Over 85  ...  Income Per Capita  Tourism  \
# 758  1536705.0            0.181819  214359.0  ...        1593.943627    6.872
#
#          Area   Built Area  Municipal  Household  Recovered  Recicled  \
# 758  785350.0  483909.1095    22315.0     3356.0     5992.0    1846.0
#
#      Compost  Disposal
# 758   1300.0       0.0
#
# [1 rows x 25 columns]

# %%
df.iloc[df[["Below Secundary"]].idxmin()]
# Out:
#      Country  Year  COU    Built  Below Secundary  Income Median   Population  \
# 1035  Russia  2017  RUS  0.14726         4.757205    5101.620911  144496738.0
#
#          Over 65  Over 65 Percentage    Over 85  ...  Income Per Capita  \
# 1035  20608462.0            0.142622  2104243.0  ...         398.016177
#
#       Tourism        Area   Built Area  Municipal  Household  Recovered  \
# 1035     4.11  17098250.0  2517888.295   80564.33     282.33    6716.88
#
#       Recicled  Compost  Disposal
# 1035   393.589  790.753  4217.051
#
# [1 rows x 25 columns]
