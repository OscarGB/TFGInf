# %%
import pandas as pd
import numpy as np
from sklearn import svm
from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import MinMaxScaler
import time
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV, ParameterGrid
from numpy import hstack
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from numpy import array
from sklearn.metrics import r2_score
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_parquet("time_dataset.parquet")

# %%
df = df[[x for x in df.columns if x not in ['Municipal', 'Household', 'Recovered', 'Recicled', 'Compost', 'Disposal']] + ['Municipal', 'Household', 'Recovered', 'Recicled', 'Compost', 'Disposal']]

# %%
cor = df.corr()
f = plt.figure(figsize=(19, 15))
plt.matshow(cor, fignum=f.number, cmap='RdBu')
plt.xticks(range(cor.shape[1]), cor.columns, fontsize=10, rotation=90)
plt.yticks(range(cor.shape[1]), cor.columns, fontsize=10)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=10)
plt.title('Covariance Matrix', fontsize=16, pad=80);

# %%
df = pd.read_parquet("dataset.parquet")

# %%
df = df[[x for x in df.columns if x not in ['Municipal', 'Household', 'Recovered', 'Recicled', 'Compost', 'Disposal']] + ['Municipal', 'Household', 'Recovered', 'Recicled', 'Compost', 'Disposal']]

# %%
cor = df.corr()
f = plt.figure(figsize=(19, 15))
plt.matshow(cor, fignum=f.number, cmap='RdBu')
plt.xticks(range(cor.shape[1]), cor.columns, fontsize=10, rotation=90)
plt.yticks(range(cor.shape[1]), cor.columns, fontsize=10)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=10)
plt.title('Covariance Matrix', fontsize=16);

# %%
df = pd.read_parquet("time_dataset.parquet")

# %%
df2 = df[['Over 85', 'Population', 'Built', 'Last Year Municipal', 'Municipal']]

# %%
cor = df2.corr()
f = plt.figure(figsize=(19, 15))
plt.matshow(cor, fignum=f.number, cmap='RdBu', vmin=-1, vmax=1)
plt.xticks(range(cor.shape[1]), cor.columns, fontsize=20, rotation=45)
plt.yticks(range(cor.shape[1]), cor.columns, fontsize=20)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=10)
plt.title('Covariance Matrix', fontsize=32, pad=80);
